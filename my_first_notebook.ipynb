# %% [markdown]
# harware is the things which we can physical parts of computer example moniter cpu keyboard
# software is the programs and backend software instructions
# examples Operating systems, apps
