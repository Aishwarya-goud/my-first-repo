# %% [markdown]
# <a href="https://colab.research.google.com/github/Aishwarya-goud/my-first-repo/blob/main/task1_load_explore_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data=pd.read_csv('ai_learning_lab.csv')
data
#shape of the dataset
data.shape
#first 5 rows
data.head()
#column names
data.columns
#data types
data.dtypes
#data info
data.info()
#missing value count for each column
data['student_name'].isnull().sum()
print(data.isnull().sum())
#Print the number of duplicate rows
duplicate_count = data.duplicated().sum()
print(f"Number of duplicate rows: {duplicate_count}")
#value counts of the topic column
print(data['topic'].value_counts())
#value counts of the attendance column.
print(data['attendance'].value_counts(normalize=True))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   student_id        110 non-null    object
#  1   student_name      110 non-null    object
#  2   batch             110 non-null    object
#  3   topic             110 non-null    object
#  4   attendance        110 non-null    object
#  5   assignment_score  98 non-null     float64
#  6   quiz_score        102 non-null    float64
#  7   lab_completed     110 non-null    object
#  8   study_hours       101 non-null    float64
#  9   feedback_rating   104 non-null    float64
#  10  tool_used         110 non-null    object
#  11  api_used          110 non-null    object
# dtypes: float64(4), object(8)
# memory usage: 10.4+ KB
# student_id           0
# student_name         0
# batch                0
# topic                0
# attendance           0
# assignment_score    12
# ...

# %%
print(data['attendance'].value_counts(normalize=True))
# Out:
# attendance
# ABSENT       0.145455
#  Present     0.145455
#  Absent      0.136364
# PRESENT      0.136364
# Present      0.136364
# Absent       0.127273
# present      0.090909
# absent       0.081818
# Name: proportion, dtype: float64
